# %% [markdown]
# ## Estadistica Aplicada
# Sesión 4-17 agosto
#
# Francisco Javier Chávez Hernández 2034204
#
# Gpo 44

# %%
#librerias 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#datos a trabajar
edades=[23,25,30,19]
personas=['Juan','Pedro', 'Ana', 'Lissa']

dicc_1={'municipio':['Escobedo','Apodaca','Monterrey','Santiago'],'nacimientos':[200,350,400,120], 'muertes': [20, 35, 40, 18], 'matrimonios':[56,68,70,19]}
datos_mun=pd.DataFrame(dicc_1)

# %%
##grafica semanal
plt.bar(personas, edades)
plt.title('Edades 4 personas')
plt.xlabel('Nombre')
plt.ylabel('Edad en años')
# Out:
# Text(0, 0.5, 'Edad en años')

# %%
plt.bar(datos_mun['municipio'], datos_mun['matrimonios'])
plt.title('Matrimonios en N.L.')
plt.xlabel('Municipio')
plt.ylabel('Cantidad matrimonios')
# Out:
# Text(0, 0.5, 'Cantidad matrimonios')

# %%
# dos graficas juntas
fig,(graf1,graf2)=plt.subplots(1,2)

#grafica 1
graf1.bar(personas, edades)

#grafica 2
graf2.bar(datos_mun['municipio'],datos_mun['matrimonios'])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Graficar con pandas
# El graficador de pandas esra construido sobre matplotlib
# dataframe.plot.tipo()

# %%
# barras 
datos_mun.plot.bar();

# %%
datos_mun['matrimonios'].plot.bar()
plt.title('titulo')
plt.ylabel('cantidad')
# Out:
# Text(0, 0.5, 'cantidad')

# %%
##
datos_mun.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
##c graficas de linea
datos_mun.plot.line();

# %%
#grafica de area
datos_mun.plot.area();

# %%
##
datos_mun['nacimientos'].plot.hist();
